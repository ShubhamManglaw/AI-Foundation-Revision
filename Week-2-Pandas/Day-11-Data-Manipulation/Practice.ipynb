# %% [markdown]
# # Independent Pandas Practice
# Each question reloads students.csv.

# %% [markdown]
# ## Question 1
# **Rename one column**
#
# Rename 'Name' to 'Student_Name'.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below
df=df.rename(columns={
    "Name":"Student_Name"
})


df
# Out:
#    Student_ID Student_Name  Age  Class  Math  Physics  Computer  Average
# 0         101      Shubham   20  CSE-A    90       88        95       91
# 1         102         Amit   21  CSE-A    80       76        84       80
# 2         103        Priya   20  CSE-B    92       94        90       92
# 3         104        Rahul   22  CSE-B    70       68        72       70
# 4         105         Neha   21  CSE-C    85       82        88       85
# 5         106        Karan   20  CSE-C    78       80        79       79
# 6         107        Sonia   21  CSE-A    96       95        98       96
# 7         108        Arjun   22  CSE-B    67       70        65       67
# 8         109         Riya   20  CSE-C    89       91        90       90
# 9         110        Vikas   21  CSE-A    75       73        78       75

# %% [markdown]
# ### Checker

# %%
print("✅ Correct" if "Student_Name" in df.columns and "Name" not in df.columns else "❌ Incorrect")
# Out:
# ✅ Correct

# %% [markdown]
# ### Reference Solution

# %%
df=df.rename(columns={"Name":"Student_Name"})

# %% [markdown]
# ## Question 2
# **Rename three columns**
#
# Rename Name→Student_Name, Computer→Computer_Science, Class→Section.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below
df=df.rename(columns={
    "Name":"Student_Name",
    "Computer":"Computer_Science",
    "Class":"Section"
})


df
# Out:
#    Student_ID Student_Name  Age Section  Math  Physics  Computer_Science  \
# 0         101      Shubham   20   CSE-A    90       88                95
# 1         102         Amit   21   CSE-A    80       76                84
# 2         103        Priya   20   CSE-B    92       94                90
# 3         104        Rahul   22   CSE-B    70       68                72
# 4         105         Neha   21   CSE-C    85       82                88
# 5         106        Karan   20   CSE-C    78       80                79
# 6         107        Sonia   21   CSE-A    96       95                98
# 7         108        Arjun   22   CSE-B    67       70                65
# 8         109         Riya   20   CSE-C    89       91                90
# 9         110        Vikas   21   CSE-A    75       73                78
#
#    Average
# 0       91
# 1       80
# 2       92
# 3       70
# 4       85
# 5       79
# 6       96
# 7       67
# 8       90
# 9       75

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")
# Out:
# Run your code and inspect the result. Independent exercise.

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 3
# **Drop first row**
#
# Remove the first row.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below
df=df.drop(index=[0])

df
# Out:
#    Student_ID   Name  Age  Class  Math  Physics  Computer  Average
# 1         102   Amit   21  CSE-A    80       76        84       80
# 2         103  Priya   20  CSE-B    92       94        90       92
# 3         104  Rahul   22  CSE-B    70       68        72       70
# 4         105   Neha   21  CSE-C    85       82        88       85
# 5         106  Karan   20  CSE-C    78       80        79       79
# 6         107  Sonia   21  CSE-A    96       95        98       96
# 7         108  Arjun   22  CSE-B    67       70        65       67
# 8         109   Riya   20  CSE-C    89       91        90       90
# 9         110  Vikas   21  CSE-A    75       73        78       75

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")
# Out:
# Run your code and inspect the result. Independent exercise.

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution
df=df.drop(index=[0])
# Out:
#   Cell In[11], line 2
#     df=df.drop(df.index=-1)
#                ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# ## Question 4
# **Drop last row**
#
# Remove the last row.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below

df=df.drop(index=[-1])

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 7
#       3 df=pd.read_csv("students.csv")
#       4
#       5 # Write your solution below
#       6
# ----> 7 df=df.drop(index=[-1])
#       8
#       9 df
#
# File ~/Desktop/AI-Foundation-Revision/.venv/lib/python3.14/site-packages/pandas/core/frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# ...

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 5
# **Drop rows by index**
#
# Remove rows with index 1 and 3.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 6
# **Drop two columns**
#
# Remove Age and Class.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 7
# **Insert constant column**
#
# Insert Bonus_Marks with value 5.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 8
# **Insert calculated column**
#
# Create Total=Math+Physics+Computer.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 9
# **Move column first**
#
# Move Average to first.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 10
# **Move column last**
#
# Move Average to last.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 11
# **Set Student_ID index**
#
# Set Student_ID as index.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 12
# **Set Student_Name index**
#
# Set Name as index.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 13
# **Reset index**
#
# Reset the index.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 14
# **Custom index**
#
# Create S1,S2,...

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 15
# **Reverse reindex**
#
# Reverse row order with reindex.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 16
# **Reindex missing labels**
#
# Add X1,S2 labels.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 17
# **Save CSV**
#
# Save student_report.csv.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 18
# **Rename dict**
#
# Rename using dictionary.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 19
# **Rename function**
#
# Convert headers to uppercase.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 20
# **Drop duplicates**
#
# Remove duplicate rows.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 21
# **Passed column**
#
# Create Passed column.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 22
# **Alphabetical columns**
#
# Sort columns alphabetically.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 23
# **Backup**
#
# Create backup copy.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 24
# **Unique index**
#
# Verify index uniqueness.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution

# %% [markdown]
# ## Question 25
# **Restore**
#
# Restore from backup.

# %%
import pandas as pd

df=pd.read_csv("students.csv")

# Write your solution below


df

# %% [markdown]
# ### Checker

# %%
print("Run your code and inspect the result. Independent exercise.")

# %% [markdown]
# ### Reference Solution

# %%
# Reference solution
